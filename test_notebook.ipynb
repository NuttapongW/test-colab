# %%
import os
import json

os.environ.get("HOSTNAME")
# Out:
# 'ip-172-21-62-249.ec2.internal'

# %%
print("Add another line before commit the second time")

print("Add code for some random stuff")
# Out:
# Add another line before commit the second time
# Add code for some random stuff

# %%
import random

for _ in range(100):
    print("".join(map(chr, random.choices(range(65, 65+26), k=20))))
# Out:
# JSUGKKNJDFXCXISFKZIV
# ZFAKBGTYLKSWJZIAENZE
# FLRUQREIHCHTTMOBSYRQ
# ZRJREHADCJBYFKWDEWDQ
# ZVYZWPYMBHZBJCLPLZLC
# NXBFZWCHRMJGZHULEPOB
# DWGMFJKBVQMZUXFJHXFJ
# RAJGPUVVRKSZYQWIBUMI
# IBACDIVLVPFHVSEWYVAR
# RXMAXDHVJWLZRHLXKXDB
# ADMOXTEWXMNTVBLZVASL
# XIDELUZCJOGOEXTBZLHH
# ELULAGLVHZZNPLSPPYGV
# GXPMJRKFUUBJUVZWEQWM
# MMFLNQKHRNOHXDMTIDMT
# YYPDZISCLFZUAMBNOBRH
# QDGOKXVAYLJFQWFGSUVI
# LZHJOBHUOVOPYFRNGMAY
# CMLOIWCTJGLDHHLXENRI
# AVLRJZUNHTFBFQKLPWKU
# YYHQVLBOUUVFFKHYSJYG
# TMVEZWNYALNVQEEQUQXL
# AKKXKFQYXVQSHVWJINPM
# NSSJDAPJQVZIVHUUAPFD
# WYUZJKVINZVEITKOURYQ
# FVNRNIRRQXJWBPAMNFSP
# FBFZKAKAOTCVLXDLOKHG
# HLYGCEVUVYNCTSPXAMPN
# KTOMCBAVQOMGCFFXHMCS
# XITXDIGOBMNIHTDDPAFS
# YAQSWJLBYMXZVDQPSFTI
# AUAQXDNSLBFUXMBOSYKD
# KVTDVMVXEITVZRGSSCET
# AMYJHKXTENRWWPSXYIBO
# FCBOBNUZDITWLIGAVVFF
# BZIOLZOWSTPTTPWPHPIS
# KSEOHNVIIHOTYHJUBYSI
# HWMQQIHGVYNKDJQCFYWY
# WAJIJUOPWHGLQHJWEIEK
# NUDOJDVBROMCWCLSJUQU
# YCAEQGGLLSQMCQAZSQFE
# GCBDMXHVLISNHJRTBSPF
# SMMPIXVWXYOEWWBSZHBB
# ...
