# %%
import os
import json

os.environ.get("HOSTNAME")
# Out:
# 'ip-172-21-62-249.ec2.internal'

# %%
print("Add another line before commit the second time")
# Out:
# Add another line before commit the second time

# %%
import random

for _ in range(100):
    print("".join(map(chr, random.choices(range(65, 65+26), k=150))))
# Out:
# CUEYAVQGHGXZIWSEPQUCXNYWYJONLLJCELHLEWHCZNKJFAGXULKHMAYQIATLOQTNMVJJTUKRPXXMUSWCTNDGLZWDAVRTEPIHXSWTKIEGXYDUMGGOWTDHLIJRJQCVQIYHRWLIHOLLJWSHBGPQVMVBEY
# NHFMJLLNWAUTHXAFDBMLZEGMPUEYCCJKIDGSMNOXBYPAGRPLPFGETUBKEJLTHWFBGAQPKMTKBWEGVZBOSLRLRIYCGIQFSXOBTXYGZOCTQGXMDYIOIBXWRXEHWVCHVATAIBHVXYOOLXHVSXNTBJZGYN
# LEVKUKOBXWUZICFGKAORROSIXDWLSKKVAEDGBMDCOXVPYOXYRJKGTEYZDOABTLDRYFCHGONQGNVBXBIQCPFEESFHIQOGXMMIQUYGKMCCLURGMKIOJNWYDFRZCWSBWZKOGFDPTOSYTZYPNWHASKQLLD
# HYPZSHXCTARGFBRHUSELNYLSSJUOGYTMVQQPSMTRMRCZVDQNYAAPVXHWCBQCNRKOFEERINEKDVVTUBZVEBZNQGDYDNKETZXLCOEGYLTXKXUVCVJSVKCOKZWHQDJSKQAWWGLXMROITTQJPVHYOWUEUP
# DQFGQKCEPXVBZLVXJVUNMDOIBNYWNJJYNIOFBSUFOBFXXSRTOWIRYRSCPXHZSPIOVRRXYPAYGPCAGWCAFQDOEIIYSEEGZTXXOZYZHCMVBTHOCPDPBDZDHUQOEJHWNEEDIMLJTJKQSEFJNJMSLJGBRQ
# GZVJVJEPXEBBXIVTVJHENQLRTNPZQHDYPIXDZGKDQUYJWYOLKYQHKHACLIVZOFNZDRJTBOTQMMONOMRQVERSUZOURGAACPVZARCHWGPEUJIGXGNAUPXIHZIIHKFKCNJESNBKNNRARIUNMLDPROCCYW
# ...
